# %%
import pandas as pd

# %%
ls -lah
# Out:
# total 20K
# drwxrwxr-x 4 alekum alekum 4.0K May 19 19:22 ./
# drwxrwxr-x 5 alekum alekum 4.0K May 19 19:02 ../
# drwxr-xr-x 2 alekum alekum 4.0K May 19 19:07 .ipynb_checkpoints/
# drwxrwxr-x 2 alekum alekum 4.0K May 19 19:10 lesson_01/
# -rw-rw-r-- 1 alekum alekum  749 May 19 19:22 Week1.ipynb

# %%
train = pd.read_csv('lesson_01/00_titanic_train.csv')

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
train.shape
# Out:
# (891, 12)

# %%
train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
train.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
train.head(4).T
# Out:
#                                    0  \
# PassengerId                        1
# Survived                           0
# Pclass                             3
# Name         Braund, Mr. Owen Harris
# Sex                             male
# Age                               22
# SibSp                              1
# Parch                              0
# Ticket                     A/5 21171
# Fare                            7.25
# Cabin                            NaN
# Embarked                           S
#
#                                                              1  \
# PassengerId                                                  2
# Survived                                                     1
# Pclass                                                       1
# Name         Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                     female
# Age                                                         38
# ...

# %%
transpose_train = train.T

# %%
print(transpose_train.index)
print(transpose_train.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')
# RangeIndex(start=0, stop=891, step=1)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %% [raw]
# import numpy

# %%
import numpy
from collections import Counter

# %%
t = train.describe()

# %%
t['Survived'].astype('int')
# Out:
# count    891
# mean       0
# std        0
# min        0
# 25%        0
# 50%        0
# 75%        1
# max        1
# Name: Survived, dtype: int64

# %%
train.describe(percentiles=[0.99])
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 99%     882.100000    1.000000    3.000000   65.870000    5.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 50%      0.000000   14.454200
# 99%      4.000000  249.006220
# max      6.000000  512.329200

# %%
tmp = train[
    train['Embarked'].isin(['Q','C']) & (train['Age'] < 40)
].head()

# %%
tmp
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 9            10         1       2
# 16           17         0       3
# 22           23         1       3
# 34           35         0       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 16                               Rice, Master. Eugene    male   2.0      4
# 22                        McGowan, Miss. Anna "Annie"  female  15.0      0
# 34                            Meyer, Mr. Edgar Joseph    male  28.0      1
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 9       0    237736  30.0708   NaN        C
# 16      1    382652  29.1250   NaN        Q
# 22      0    330923   8.0292   NaN        Q
# 34      0  PC 17604  82.1708   NaN        C

# %%
train.sort_values('Fare')
# Out:
#      PassengerId  Survived  Pclass  \
# 271          272         1       3
# 597          598         0       3
# 302          303         0       3
# 633          634         0       1
# 277          278         0       2
# 413          414         0       2
# 674          675         0       2
# 263          264         0       1
# 466          467         0       2
# 732          733         0       2
# 179          180         0       3
# 806          807         0       1
# 481          482         0       2
# 822          823         0       1
# 815          816         0       1
# 378          379         0       3
# 872          873         0       1
# 326          327         0       3
# 843          844         0       3
# 818          819         0       3
# 371          372         0       3
# 202          203         0       3
# 654          655         0       3
# 143          144         0       3
# 411          412         0       3
# ...

# %%
train[['Age', 'Sex']].groupby('Sex').mean()
# Out:
#               Age
# Sex
# female  27.915709
# male    30.726645

# %%
train.pivot_table('PassengerId', 'Pclass', 'Survived', 'count')
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
# %matplotlib inline

# %%
from matplotlib import pyplot as plt

# %%
plt.plot([1,2,3,4])

# %%
plt.plot([4,2,1,3], [1,3,2,4], '-')

# %%
plt.hist([1,2,3,1,3,1,4,4,5,5,5])
# Out:
# (array([3., 0., 1., 0., 0., 2., 0., 2., 0., 3.]),
#  array([1. , 1.4, 1.8, 2.2, 2.6, 3. , 3.4, 3.8, 4.2, 4.6, 5. ]),
#  <a list of 10 Patch objects>)

# %%
import pandas as pd
df = pd.read_csv('lesson_01/00_sberbank_macro.csv')

# %%
df
# Out:
#        timestamp  oil_urals  gdp_quart  gdp_quart_growth    cpi    ppi  \
# 0     2010-01-01    76.1000        NaN               NaN    NaN    NaN
# 1     2010-01-02    76.1000        NaN               NaN    NaN    NaN
# 2     2010-01-03    76.1000        NaN               NaN    NaN    NaN
# 3     2010-01-04    76.1000        NaN               NaN    NaN    NaN
# 4     2010-01-05    76.1000        NaN               NaN    NaN    NaN
# 5     2010-01-06    76.1000        NaN               NaN    NaN    NaN
# 6     2010-01-07    76.1000        NaN               NaN    NaN    NaN
# 7     2010-01-08    76.1000        NaN               NaN    NaN    NaN
# 8     2010-01-09    76.1000        NaN               NaN    NaN    NaN
# 9     2010-01-10    76.1000        NaN               NaN    NaN    NaN
# 10    2010-01-11    76.1000        NaN               NaN    NaN    NaN
# 11    2010-01-12    76.1000        NaN               NaN    NaN    NaN
# ...

# %%
df[~df['mortality'].isnull()]['mortality'].hist()

# %%
df['rent_price_1room_eco'].hist(bins=100)

# %%
tmp = df[['timestamp', 'oil_urals', 'gdp_quart_growth']]

# %%
tmp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2484 entries, 0 to 2483
# Data columns (total 3 columns):
# timestamp           2484 non-null datetime64[ns]
# oil_urals           2484 non-null float64
# gdp_quart_growth    2394 non-null float64
# dtypes: datetime64[ns](1), float64(2)
# memory usage: 58.3 KB

# %%
tmp.set_index('timestamp').plot()

# %%
tmp.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f979c268358>,
# ...
#       dtype=object)

# %%
plt.plot(
    df[~df['gdp_quart_growth'].isnull()]['gdp_quart'],
    df[~df['gdp_quart_growth'].isnull()]['oil_urals'],
    '.'
)

# %%
import seaborn as sns
